# %%
# load required python libraries
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# load data
timeseries_data = pd.read_csv("./data/csv/ncdc-covid19-dailyupdates.csv")
spatial_data = gpd.read_file("./data/shp/ncdc-covid19-states.shp")

# %%
timeseries_data.head()
# Out:
#          Date  Total Confirmed  New Cases  Active Cases  Deaths  Recoveries
# 0  24/03/2020               44          4            41       1           2
# 1  23/03/2020               40         10            37       1           2
# 2  22/03/2020               30          8            28       0           2
# 3  21/03/2020               22         10            20       0           2
# 4  19/03/2020               12          4            12       0           0

# %%
label = timeseries_data['Date']
confirmed = timeseries_data['Date']
recovered = timeseries_data['Recoveries']
deaths = timeseries_data['Deaths']

# %%
# map
spatial_data.plot(column="CASES", categorical=True, legend=True, figsize=(20,20))
